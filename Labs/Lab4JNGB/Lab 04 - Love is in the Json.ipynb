# %% [markdown]
# # Valentine's Day Lab Assignment
# Picking a Romantic Movie
#
# ## Instructions:
# 1. Download a dataset of romantic movies from a public dataset repository (e.g., Kaggle).
#    - Example dataset: "Romantic Movies Dataset" (ensure it's in JSON format).
# 2. Load the dataset from the JSON file.
# 3. Create a function that helps pick a romantic movie based on user preferences.
# 4. Display the selected movie details.
# 5. Verify the JSON file content

# %%
#submitted!
#sorry for the wait, some crazy ish going down in my life rn, but you know damn well ill still do these labs 
#gonna use the same dataset as jayvee bc i was having a hard time finding one simple enough and his is good

import json

romanticmoviesdataset = [
    {
        "title": "The Notebook",
        "year_of_release": "2004",
        "rating_score": "7.8",
        "box_office_amount": "115.6"
    },
    {
        "title": "P.S. I Love You",
        "year_of_release": "2007",
        "rating_score": "7.0",
        "box_office_amount": "156.8"
    },
    {
        "title": "Titanic",
        "year_of_release": "1997",
        "rating_score": "7.8",
        "box_office_amount": "2187.5"
    },
    {
        "title": "A Walk to Remember",
        "year_of_release": "2002",
        "rating_score": "7.3",
        "box_office_amount": "47.5"
    },
    {
        "title": "La La Land",
        "year_of_release": "2016",
        "rating_score": "8.0",
        "box_office_amount": "446.1"
    },
    {
        "title": "Pride and Prejudice",
        "year_of_release": "2005",
        "rating_score": "7.8",
        "box_office_amount": "121.6"
    },
    {
        "title": "Crazy Rich Asians",
        "year_of_release": "2018",
        "rating_score": "7.0",
        "box_office_amount": "238.5"
    },
    {
        "title": "The Fault in Our Stars",
        "year_of_release": "2014",
        "rating_score": "7.7",
        "box_office_amount": "307.2"
    },
    {
        "title": "Me Before You",
        "year_of_release": "2016",
        "rating_score": "7.4",
        "box_office_amount": "208.3"
    },
    {
        "title": "The Vow",
        "year_of_release": "2012",
        "rating_score": "6.8",
        "box_office_amount": "196.1"
    },
    {
        "title": "Love Actually",
        "year_of_release": "2003",
        "rating_score": "7.6",
        "box_office_amount": "246.9"
    },
    {
        "title": "Notting Hill",
        "year_of_release": "1999",
        "rating_score": "7.1",
        "box_office_amount": "364.0"
    },
    {
        "title": "Pretty Woman",
        "year_of_release": "1990",
        "rating_score": "7.1",
        "box_office_amount": "463.4"
    },
    {
        "title": "When Harry Met Sally",
        "year_of_release": "1989",
        "rating_score": "7.6",
        "box_office_amount": "92.8"
    },
    {
        "title": "10 Things I Hate About You",
        "year_of_release": "1999",
        "rating_score": "7.3",
        "box_office_amount": "53.5"
    },
    {
        "title": "The Princess Bride",
        "year_of_release": "1987",
        "rating_score": "8.1",
        "box_office_amount": "30.9"
    },
    {
        "title": "Sleepless in Seattle",
        "year_of_release": "1993",
        "rating_score": "6.8",
        "box_office_amount": "227.8"
    },
    {
        "title": "You've Got Mail",
        "year_of_release": "1998",
        "rating_score": "6.7",
        "box_office_amount": "250.8"
    },
    {
        "title": "The Holiday",
        "year_of_release": "2006",
        "rating_score": "6.9",
        "box_office_amount": "205.1"
    },
    {
        "title": "To All the Boys I've Loved Before",
        "year_of_release": "2018",
        "rating_score": "7.1",
        "box_office_amount": "0.0"
    },
    {
        "title": "The Shape of Water",
        "year_of_release": "2017",
        "rating_score": "7.3",
        "box_office_amount": "195.2"
    },
    {
        "title": "Call Me by Your Name",
        "year_of_release": "2017",
        "rating_score": "7.9",
        "box_office_amount": "41.9"
    },
    {
        "title": "The Big Sick",
        "year_of_release": "2017",
        "rating_score": "7.5",
        "box_office_amount": "56.4"
    },
    {
        "title": "Silver Linings Playbook",
        "year_of_release": "2012",
        "rating_score": "7.7",
        "box_office_amount": "236.4"
    },
    {
        "title": "Her",
        "year_of_release": "2013",
        "rating_score": "8.0",
        "box_office_amount": "48.3"
    },
    {
        "title": "500 Days of Summer",
        "year_of_release": "2009",
        "rating_score": "7.7",
        "box_office_amount": "60.7"
    },
    {
        "title": "Eternal Sunshine of the Spotless Mind",
        "year_of_release": "2004",
        "rating_score": "8.3",
        "box_office_amount": "74.0"
    },
    {
        "title": "Before Sunrise",
        "year_of_release": "1995",
        "rating_score": "8.1",
        "box_office_amount": "5.5"
    },
    {
        "title": "Before Sunset",
        "year_of_release": "2004",
        "rating_score": "8.1",
        "box_office_amount": "15.8"
    },
    {
        "title": "Before Midnight",
        "year_of_release": "2013",
        "rating_score": "7.9",
        "box_office_amount": "23.3"
    },
    {
        "title": "The Spectacular Now",
        "year_of_release": "2013",
        "rating_score": "7.1",
        "box_office_amount": "6.9"
    },
    {
        "title": "The Perks of Being a Wallflower",
        "year_of_release": "2012",
        "rating_score": "8.0",
        "box_office_amount": "33.4"
    },
    {
        "title": "The Best of Me",
        "year_of_release": "2014",
        "rating_score": "6.7",
        "box_office_amount": "35.9"
    },
    {
        "title": "Dear John",
        "year_of_release": "2010",
        "rating_score": "6.3",
        "box_office_amount": "114.9"
    },
    {
        "title": "The Lucky One",
        "year_of_release": "2012",
        "rating_score": "6.5",
        "box_office_amount": "99.4"
    },
    {
        "title": "Safe Haven",
        "year_of_release": "2013",
        "rating_score": "6.7",
        "box_office_amount": "97.6"
    },
    {
        "title": "The Longest Ride",
        "year_of_release": "2015",
        "rating_score": "7.1",
        "box_office_amount": "63.0"
    },
    {
        "title": "The Choice",
        "year_of_release": "2016",
        "rating_score": "6.6",
        "box_office_amount": "23.4"
    },
    {
        "title": "The Time Traveler's Wife",
        "year_of_release": "2009",
        "rating_score": "7.1",
        "box_office_amount": "101.3"
    },
    {
        "title": "About Time",
        "year_of_release": "2013",
        "rating_score": "7.8",
        "box_office_amount": "87.1"
    },
    {
        "title": "The Age of Adaline",
        "year_of_release": "2015",
        "rating_score": "7.2",
        "box_office_amount": "65.7"
    },
    {
        "title": "The Great Gatsby",
        "year_of_release": "2013",
        "rating_score": "7.2",
        "box_office_amount": "353.6"
    },
    {
        "title": "The Proposal",
        "year_of_release": "2009",
        "rating_score": "6.7",
        "box_office_amount": "317.4"
    },
    {
        "title": "The Spectacular Now",
        "year_of_release": "2013",
        "rating_score": "7.1",
        "box_office_amount": "6.9"
    },
    {
        "title": "The Perks of Being a Wallflower",
        "year_of_release": "2012",
        "rating_score": "8.0",
        "box_office_amount": "33.4"
    },
    {
        "title": "The Best of Me",
        "year_of_release": "2014",
        "rating_score": "6.7",
        "box_office_amount": "35.9"
    },
    {
        "title": "Dear John",
        "year_of_release": "2010",
        "rating_score": "6.3",
        "box_office_amount": "114.9"
    },
    {
        "title": "The Lucky One",
        "year_of_release": "2012",
        "rating_score": "6.5",
        "box_office_amount": "99.4"
    },
    {
        "title": "Safe Haven",
        "year_of_release": "2013",
        "rating_score": "6.7",
        "box_office_amount": "97.6"
    },
    {
        "title": "The Longest Ride",
        "year_of_release": "2015",
        "rating_score": "7.1",
        "box_office_amount": "63.0"
    }
]
filename = 'romanticmoviesdataset.json'
with open(filename, 'w') as f:
    json.dump(romanticmoviesdataset, f, indent=2)

# %%
#my code
import json

with open ('romanticmoviesdataset.json', 'r')as f: 
    romanticmovies = json.load(f)

def movie_search(movies, min_rating, max_year):
    matches = []  #asked for jayvee's help on part of this, but the example made it easy to get the right idea
    for movie in movies:
        rating = float(movie['rating_score'])
        year = int(movie['year_of_release'])
        if rating >= min_rating and year <= max_year:
            matches.append(movie)
        else:
            continue #was unaware of continue action previous to this, feels very demanding and rude ngl
    return matches

min_rating = float(input("Enter the minimum rating (0-10): ")) #lines 18-21 pretty much direct from example, useful to figure out function for sorting
max_year = int(input("Enter the latest release year you wish to see: "))

the_chosen_ones = movie_search(romanticmovies, min_rating, max_year) 

if not the_chosen_ones: #tried to make it print the movies first and have the else be the "no movies match" but my brain farted so used "not"
    print ("No movies match the criteria you selected.")
else:
    for movie in the_chosen_ones:
        print(f"Selected Movie: {movie['title']}")
        print(f"Year: {movie['year_of_release']}")
        print(f"Rating: {movie['rating_score']}")
        print(f"Box Office: ${movie['box_office_amount']} million")
        print(f"  ") #space between outputs
# Out:
# Selected Movie: Titanic
# Year: 1997
# Rating: 7.8
# Box Office: $2187.5 million
#
# Selected Movie: A Walk to Remember
# Year: 2002
# Rating: 7.3
# Box Office: $47.5 million
#
# Selected Movie: Notting Hill
# Year: 1999
# Rating: 7.1
# Box Office: $364.0 million
#
# Selected Movie: Pretty Woman
# Year: 1990
# Rating: 7.1
# Box Office: $463.4 million
#
# Selected Movie: When Harry Met Sally
# Year: 1989
# Rating: 7.6
# Box Office: $92.8 million
#
# Selected Movie: 10 Things I Hate About You
# Year: 1999
# Rating: 7.3
# Box Office: $53.5 million
#
# Selected Movie: The Princess Bride
# Year: 1987
# Rating: 8.1
# Box Office: $30.9 million
#
# Selected Movie: Sleepless in Seattle
# Year: 1993
# Rating: 6.8
# Box Office: $227.8 million
#
# Selected Movie: You've Got Mail
# Year: 1998
# Rating: 6.7
# Box Office: $250.8 million
#
# Selected Movie: Before Sunrise
# Year: 1995
# Rating: 8.1
# Box Office: $5.5 million

# %%
# Sample Code:
min_rating = float(input("Enter the minimum rating (0-10): "))
max_year = int(input("Enter the latest release year: "))

selected_movie = pick_movie(data, min_rating, max_year)

if isinstance(selected_movie, str):
    print(selected_movie)
else:
    print(f"Selected Movie: {selected_movie['Title']}")
    print(f"Year: {selected_movie['Year']}")
    print(f"Rating: {selected_movie['Rating']}")
    print(f"Box Office: ${selected_movie['BoxOffice']} million")
